# %%
import drawdata
from drawdata import draw_line


line_plot = draw_line()
line_plot
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/line.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd

# Reading the clipboard into a DataFrame
df = pd.read_clipboard(sep=",")
print(df)
# Out:
#        x           y  z
# 0    104   94.600006  a
# 1    105   94.600006  a
# 2    105   94.600006  a
# 3    106   94.600006  a
# 4    107   94.600006  a
# ..   ...         ... ..
# 274  258  339.600006  a
# 275  258  340.600006  a
# 276  258  341.600006  a
# 277  259  341.600006  a
# 278  259  342.600006  a
#
# [279 rows x 3 columns]
